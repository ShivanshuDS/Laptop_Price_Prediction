# %% [markdown]
# ### Project2
# :-<br>
# Laptop data

# %%
# pip install pandas

# %%
import pandas as pd

# %%
df=pd.read_csv('laptopPrice.csv') #ye csv file ko read kar raha h

# %%
df # ye df variable bale file ko show kara raha h ek data frame ki tarh
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df.drop('rating',axis=1) # ye rating ko drop kar raha h but temperory tarike se
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df # uper  me rating ka column drop kiya tha but isme show ho raha h
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df.drop(['rating','Number of Ratings','Number of Reviews'],axis=1,inplace=True)# ye jo drop me three columns permently delelte ho gye kiyu inplace=True ko use karoge to permanetly delete ho jayega

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df.isnull().sum() #ye null value ko dikha raha h
# Out:
# brand              0
# processor_brand    0
# processor_name     0
# processor_gnrtn    0
# ram_gb             0
# ram_type           0
# ssd                0
# hdd                0
# os                 0
# os_bit             0
# graphic_card_gb    0
# weight             0
# warranty           0
# Touchscreen        0
# msoffice           0
# Price              0
# dtype: int64

# %%
df.duplicated().sum()# ye total kitni duplicate value h ye dikha raha h
# Out:
# np.int64(37)

# %%
df.drop_duplicates(inplace=True)# permently drop ho gyi duplicte value

# %%
df.duplicated().sum()# ye total kitni duplicate value h ye dikha raha h
# Out:
# np.int64(0)

# %%
df[['brand']]
# Out:
#       brand
# 0      ASUS
# 1    Lenovo
# 2    Lenovo
# 3      ASUS
# 4      ASUS
# ..      ...
# 818    ASUS
# 819    ASUS
# 820    ASUS
# 821    ASUS
# 822  Lenovo
#
# [786 rows x 1 columns]

# %%
df['brand'].unique()#brand ke columns ki unique value find kar li
# Out:
# <StringArray>
# ['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE']
# Length: 8, dtype: str

# %%
df['brand'].value_counts()
# Out:
# brand
# ASUS      234
# DELL      147
# Lenovo    143
# HP        134
# acer       51
# MSI        49
# APPLE      22
# Avita       6
# Name: count, dtype: int64

# %%
brand_dict={
    'ASUS':10, 'Lenovo':20, 'acer':30, 'Avita':40, 'HP':50, 'DELL':60, 'MSI':70, 'APPLE':80
}

# %%
df['brand']=df['brand'].map(brand_dict)#brand columns ki encoding kar di

# %%
df # ab show kar liya
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0       10           Intel        Core i3            10th   4 GB     DDR4
# 1       20           Intel        Core i3            10th   4 GB     DDR4
# 2       20           Intel        Core i3            10th   4 GB     DDR4
# 3       10           Intel        Core i5            10th   8 GB     DDR4
# 4       10           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..     ...             ...            ...             ...    ...      ...
# 818     10             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819     10             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820     10             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821     10             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822     20             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb      weight  \
# ...

# %%
df[['processor_brand']]
# Out:
#     processor_brand
# 0             Intel
# 1             Intel
# 2             Intel
# 3             Intel
# 4             Intel
# ..              ...
# 818             AMD
# 819             AMD
# 820             AMD
# 821             AMD
# 822             AMD
#
# [786 rows x 1 columns]

# %%
df['processor_brand'].unique()
# Out:
# <StringArray>
# ['Intel', 'AMD', 'M1']
# Length: 3, dtype: str

# %%
df['processor_brand'].value_counts()
# Out:
# processor_brand
# Intel    582
# AMD      185
# M1        19
# Name: count, dtype: int64

# %%
processor_brand_dict={
    'Intel':1, 'AMD':2, 'M1':3
}

# %%
df['processor_brand']=df['processor_brand'].map(processor_brand_dict)

# %%
df
# Out:
#      brand  processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0       10                1        Core i3            10th   4 GB     DDR4
# 1       20                1        Core i3            10th   4 GB     DDR4
# 2       20                1        Core i3            10th   4 GB     DDR4
# 3       10                1        Core i5            10th   8 GB     DDR4
# 4       10                1   Celeron Dual   Not Available   4 GB     DDR4
# ..     ...              ...            ...             ...    ...      ...
# 818     10                2        Ryzen 9   Not Available   4 GB     DDR4
# 819     10                2        Ryzen 9   Not Available   4 GB     DDR4
# 820     10                2        Ryzen 9   Not Available   4 GB     DDR4
# 821     10                2        Ryzen 9   Not Available   4 GB     DDR4
# 822     20                2        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df[['processor_name']]
# Out:
#     processor_name
# 0          Core i3
# 1          Core i3
# 2          Core i3
# 3          Core i5
# 4     Celeron Dual
# ..             ...
# 818        Ryzen 9
# 819        Ryzen 9
# 820        Ryzen 9
# 821        Ryzen 9
# 822        Ryzen 5
#
# [786 rows x 1 columns]

# %%
df['processor_name'].unique()
# Out:
# <StringArray>
# [     'Core i3',      'Core i5', 'Celeron Dual',      'Ryzen 5',
#       'Core i7',      'Core i9',           'M1', 'Pentium Quad',
#       'Ryzen 3',      'Ryzen 7',      'Ryzen 9']
# Length: 11, dtype: str

# %%
df['processor_name'].value_counts()
# Out:
# processor_name
# Core i5         277
# Core i3         157
# Core i7         104
# Ryzen 5          80
# Ryzen 7          55
# Ryzen 3          26
# Ryzen 9          25
# Celeron Dual     23
# M1               19
# Pentium Quad     12
# Core i9           8
# Name: count, dtype: int64

# %%
processor_name_dict={
    'Core i3':3,      'Core i5':5, 'Celeron Dual':1,      'Ryzen 5':6,
      'Core i7':7,      'Core i9':9,           'M1':4, 'Pentium Quad':2,
      'Ryzen 3':11,      'Ryzen 7':8,      'Ryzen 9':10
}

# %%
df['processor_name']=df['processor_name'].map(processor_name_dict)

# %%
df
# Out:
#      brand  processor_brand  processor_name processor_gnrtn ram_gb ram_type  \
# 0       10                1               3            10th   4 GB     DDR4
# 1       20                1               3            10th   4 GB     DDR4
# 2       20                1               3            10th   4 GB     DDR4
# 3       10                1               5            10th   8 GB     DDR4
# 4       10                1               1   Not Available   4 GB     DDR4
# ..     ...              ...             ...             ...    ...      ...
# 818     10                2              10   Not Available   4 GB     DDR4
# 819     10                2              10   Not Available   4 GB     DDR4
# 820     10                2              10   Not Available   4 GB     DDR4
# 821     10                2              10   Not Available   4 GB     DDR4
# 822     20                2               6            10th   8 GB     DDR4
#
# ...

# %%
df[['processor_gnrtn']]
# Out:
#     processor_gnrtn
# 0              10th
# 1              10th
# 2              10th
# 3              10th
# 4     Not Available
# ..              ...
# 818   Not Available
# 819   Not Available
# 820   Not Available
# 821   Not Available
# 822            10th
#
# [786 rows x 1 columns]

# %%
df['processor_gnrtn'].unique()
# Out:
# <StringArray>
# ['10th', 'Not Available', '11th', '7th', '8th', '9th', '4th', '12th']
# Length: 8, dtype: str

# %%
df['processor_gnrtn'].value_counts()
# Out:
# processor_gnrtn
# 11th             319
# Not Available    219
# 10th             196
# 8th               35
# 7th                7
# 9th                6
# 12th               3
# 4th                1
# Name: count, dtype: int64

# %%
processor_gnrtn_dict={
    '10th':10, 'Not Available':0, '11th':11, '7th':7, '8th':8, '9th':9, '4th':4, '12th':12
}

# %%
df['processor_gnrtn']=df['processor_gnrtn'].map(processor_gnrtn_dict)

# %%
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn ram_gb ram_type  \
# 0       10                1               3               10   4 GB     DDR4
# 1       20                1               3               10   4 GB     DDR4
# 2       20                1               3               10   4 GB     DDR4
# 3       10                1               5               10   8 GB     DDR4
# 4       10                1               1                0   4 GB     DDR4
# ..     ...              ...             ...              ...    ...      ...
# 818     10                2              10                0   4 GB     DDR4
# 819     10                2              10                0   4 GB     DDR4
# 820     10                2              10                0   4 GB     DDR4
# 821     10                2              10                0   4 GB     DDR4
# 822     20                2               6               10   8 GB     DDR4
#
# ...

# %%
df[['ram_gb']]
# Out:
#     ram_gb
# 0     4 GB
# 1     4 GB
# 2     4 GB
# 3     8 GB
# 4     4 GB
# ..     ...
# 818   4 GB
# 819   4 GB
# 820   4 GB
# 821   4 GB
# 822   8 GB
#
# [786 rows x 1 columns]

# %%
df['ram_gb'].unique()
# Out:
# <StringArray>
# ['4 GB', '8 GB', '16 GB', '32 GB']
# Length: 4, dtype: str

# %%
df['ram_gb'].value_counts()
# Out:
# ram_gb
# 8 GB     393
# 4 GB     220
# 16 GB    171
# 32 GB      2
# Name: count, dtype: int64

# %%
ram_gb_dict={
    '4 GB':4, '8 GB':8, '16 GB':16, '32 GB':32
}

# %%
df['ram_gb']=df['ram_gb'].map(ram_gb_dict)

# %%
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb ram_type  \
# 0       10                1               3               10       4     DDR4
# 1       20                1               3               10       4     DDR4
# 2       20                1               3               10       4     DDR4
# 3       10                1               5               10       8     DDR4
# 4       10                1               1                0       4     DDR4
# ..     ...              ...             ...              ...     ...      ...
# 818     10                2              10                0       4     DDR4
# 819     10                2              10                0       4     DDR4
# 820     10                2              10                0       4     DDR4
# 821     10                2              10                0       4     DDR4
# 822     20                2               6               10       8     DDR4
#
# ...

# %%
df[['ram_type']]
# Out:
#     ram_type
# 0       DDR4
# 1       DDR4
# 2       DDR4
# 3       DDR4
# 4       DDR4
# ..       ...
# 818     DDR4
# 819     DDR4
# 820     DDR4
# 821     DDR4
# 822     DDR4
#
# [786 rows x 1 columns]

# %%
df['ram_type'].unique()
# Out:
# <StringArray>
# ['DDR4', 'LPDDR4', 'LPDDR4X', 'DDR5', 'DDR3', 'LPDDR3']
# Length: 6, dtype: str

# %%
df['ram_type'].value_counts()
# Out:
# ram_type
# DDR4       678
# LPDDR4X     52
# LPDDR4      27
# LPDDR3      14
# DDR5         8
# DDR3         7
# Name: count, dtype: int64

# %%
ram_type_dict={
    'DDR4':1, 'LPDDR4':2, 'LPDDR4X':3, 'DDR5':4, 'DDR3':5, 'LPDDR3':6
    }

# %%
df['ram_type']=df['ram_type'].map(ram_type_dict)

# %%
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0       10                1               3               10       4
# 1       20                1               3               10       4
# 2       20                1               3               10       4
# 3       10                1               5               10       8
# 4       10                1               1                0       4
# ..     ...              ...             ...              ...     ...
# 818     10                2              10                0       4
# 819     10                2              10                0       4
# 820     10                2              10                0       4
# 821     10                2              10                0       4
# 822     20                2               6               10       8
#
#      ram_type      ssd      hdd       os  os_bit graphic_card_gb      weight  \
# ...

# %%
df[['ssd']]
# Out:
#          ssd
# 0       0 GB
# 1       0 GB
# 2       0 GB
# 3     512 GB
# 4       0 GB
# ..       ...
# 818  1024 GB
# 819  1024 GB
# 820  1024 GB
# 821  1024 GB
# 822   512 GB
#
# [786 rows x 1 columns]

# %%
df['ssd'].unique()
# Out:
# <StringArray>
# ['0 GB', '512 GB', '256 GB', '128 GB', '1024 GB', '2048 GB', '3072 GB']
# Length: 7, dtype: str

# %%
df['ssd'].value_counts()
# Out:
# ssd
# 512 GB     379
# 256 GB     171
# 0 GB       122
# 1024 GB    108
# 128 GB       3
# 2048 GB      2
# 3072 GB      1
# Name: count, dtype: int64

# %%
ssd_dict={
    '0 GB':0, '512 GB':512, '256 GB':256, '128 GB':128, '1024 GB':1024, '2048 GB':2048, '3072 GB':3072
}

# %%
df['ssd']=df['ssd'].map(ssd_dict)

# %%
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0       10                1               3               10       4
# 1       20                1               3               10       4
# 2       20                1               3               10       4
# 3       10                1               5               10       8
# 4       10                1               1                0       4
# ..     ...              ...             ...              ...     ...
# 818     10                2              10                0       4
# 819     10                2              10                0       4
# 820     10                2              10                0       4
# 821     10                2              10                0       4
# 822     20                2               6               10       8
#
#      ram_type   ssd      hdd       os  os_bit graphic_card_gb      weight  \
# ...

# %%
df[['hdd']]
# Out:
#          hdd
# 0    1024 GB
# 1    1024 GB
# 2    1024 GB
# 3       0 GB
# 4     512 GB
# ..       ...
# 818     0 GB
# 819     0 GB
# 820     0 GB
# 821     0 GB
# 822     0 GB
#
# [786 rows x 1 columns]

# %%
df['hdd'].unique()
# Out:
# <StringArray>
# ['1024 GB', '0 GB', '512 GB', '2048 GB']
# Length: 4, dtype: str

# %%
df['hdd'].value_counts()
# Out:
# hdd
# 0 GB       588
# 1024 GB    157
# 512 GB      40
# 2048 GB      1
# Name: count, dtype: int64

# %%
hdd_dict={
    '1024 GB':1024, '0 GB':0, '512 GB':512, '2048 GB':2048
}

# %%
df['hdd']=df['hdd'].map(hdd_dict)

# %%
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0       10                1               3               10       4
# 1       20                1               3               10       4
# 2       20                1               3               10       4
# 3       10                1               5               10       8
# 4       10                1               1                0       4
# ..     ...              ...             ...              ...     ...
# 818     10                2              10                0       4
# 819     10                2              10                0       4
# 820     10                2              10                0       4
# 821     10                2              10                0       4
# 822     20                2               6               10       8
#
#      ram_type   ssd   hdd       os  os_bit graphic_card_gb      weight  \
# ...

# %%
df[['os']]
# Out:
#           os
# 0    Windows
# 1    Windows
# 2    Windows
# 3    Windows
# 4    Windows
# ..       ...
# 818  Windows
# 819  Windows
# 820  Windows
# 821  Windows
# 822      DOS
#
# [786 rows x 1 columns]

# %%
df['os'].unique()
# Out:
# <StringArray>
# ['Windows', 'DOS', 'Mac']
# Length: 3, dtype: str

# %%
df['os'].value_counts()
# Out:
# os
# Windows    748
# Mac         22
# DOS         16
# Name: count, dtype: int64

# %%
os_dict={
    'Windows':1, 'DOS':2, 'Mac':3
    }

# %%
df['os']=df['os'].map(os_dict)

# %%
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0       10                1               3               10       4
# 1       20                1               3               10       4
# 2       20                1               3               10       4
# 3       10                1               5               10       8
# 4       10                1               1                0       4
# ..     ...              ...             ...              ...     ...
# 818     10                2              10                0       4
# 819     10                2              10                0       4
# 820     10                2              10                0       4
# 821     10                2              10                0       4
# 822     20                2               6               10       8
#
#      ram_type   ssd   hdd  os  os_bit graphic_card_gb      weight  \
# 0           1     0  1024   1  64-bit            0 GB      Casual
# ...

# %%
df[['os_bit']]
# Out:
#      os_bit
# 0    64-bit
# 1    64-bit
# 2    64-bit
# 3    32-bit
# 4    64-bit
# ..      ...
# 818  64-bit
# 819  64-bit
# 820  64-bit
# 821  64-bit
# 822  64-bit
#
# [786 rows x 1 columns]

# %%
df['os_bit'].unique()
# Out:
# <StringArray>
# ['64-bit', '32-bit']
# Length: 2, dtype: str

# %%
df['os_bit'].value_counts()
# Out:
# os_bit
# 64-bit    678
# 32-bit    108
# Name: count, dtype: int64

# %%
os_bit_dict={
    '64-bit':64, '32-bit':32
}

# %%
df['os_bit']=df['os_bit'].map(os_bit_dict)

# %%
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0       10                1               3               10       4
# 1       20                1               3               10       4
# 2       20                1               3               10       4
# 3       10                1               5               10       8
# 4       10                1               1                0       4
# ..     ...              ...             ...              ...     ...
# 818     10                2              10                0       4
# 819     10                2              10                0       4
# 820     10                2              10                0       4
# 821     10                2              10                0       4
# 822     20                2               6               10       8
#
#      ram_type   ssd   hdd  os  os_bit graphic_card_gb      weight  \
# 0           1     0  1024   1      64            0 GB      Casual
# ...

# %%
df[['graphic_card_gb']]
# Out:
#     graphic_card_gb
# 0              0 GB
# 1              0 GB
# 2              0 GB
# 3              2 GB
# 4              0 GB
# ..              ...
# 818            0 GB
# 819            0 GB
# 820            4 GB
# 821            4 GB
# 822            0 GB
#
# [786 rows x 1 columns]

# %%
df['graphic_card_gb'].unique()
# Out:
# <StringArray>
# ['0 GB', '2 GB', '4 GB', '6 GB', '8 GB']
# Length: 5, dtype: str

# %%
df['graphic_card_gb'].value_counts()
# Out:
# graphic_card_gb
# 0 GB    544
# 4 GB    125
# 2 GB     66
# 6 GB     37
# 8 GB     14
# Name: count, dtype: int64

# %%
graphic_card_gb_dict={
    '0 GB':0, '2 GB':2, '4 GB':4, '6 GB':6, '8 GB':8
}

# %%
df['graphic_card_gb']=df['graphic_card_gb'].map(graphic_card_gb_dict)

# %%
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0       10                1               3               10       4
# 1       20                1               3               10       4
# 2       20                1               3               10       4
# 3       10                1               5               10       8
# 4       10                1               1                0       4
# ..     ...              ...             ...              ...     ...
# 818     10                2              10                0       4
# 819     10                2              10                0       4
# 820     10                2              10                0       4
# 821     10                2              10                0       4
# 822     20                2               6               10       8
#
#      ram_type   ssd   hdd  os  os_bit  graphic_card_gb      weight  \
# 0           1     0  1024   1      64                0      Casual
# ...

# %%
df[['weight']]
# Out:
#          weight
# 0        Casual
# 1        Casual
# 2        Casual
# 3        Casual
# 4        Casual
# ..          ...
# 818      Casual
# 819      Casual
# 820      Casual
# 821      Casual
# 822  ThinNlight
#
# [786 rows x 1 columns]

# %%
df['weight'].unique()
# Out:
# <StringArray>
# ['Casual', 'ThinNlight', 'Gaming']
# Length: 3, dtype: str

# %%
df['weight'].value_counts()
# Out:
# weight
# Casual        495
# ThinNlight    252
# Gaming         39
# Name: count, dtype: int64

# %%
weight_dict={
    'Casual':1, 'ThinNlight':2, 'Gaming':3
}

# %%
df['weight']=df['weight'].map(weight_dict)

# %%
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0       10                1               3               10       4
# 1       20                1               3               10       4
# 2       20                1               3               10       4
# 3       10                1               5               10       8
# 4       10                1               1                0       4
# ..     ...              ...             ...              ...     ...
# 818     10                2              10                0       4
# 819     10                2              10                0       4
# 820     10                2              10                0       4
# 821     10                2              10                0       4
# 822     20                2               6               10       8
#
#      ram_type   ssd   hdd  os  os_bit  graphic_card_gb  weight     warranty  \
# ...

# %%
df[['warranty']]
# Out:
#         warranty
# 0    No warranty
# 1    No warranty
# 2    No warranty
# 3    No warranty
# 4    No warranty
# ..           ...
# 818       1 year
# 819       1 year
# 820       1 year
# 821       1 year
# 822  No warranty
#
# [786 rows x 1 columns]

# %%
df['warranty'].unique()
# Out:
# <StringArray>
# ['No warranty', '1 year', '2 years', '3 years']
# Length: 4, dtype: str

# %%
df['warranty'].value_counts()
# Out:
# warranty
# 1 year         484
# No warranty    266
# 2 years         23
# 3 years         13
# Name: count, dtype: int64

# %%
warranty_dict={
    'No warranty':0, '1 year':1, '2 years':2, '3 years':3
}

# %%
df['warranty']=df['warranty'].map(warranty_dict)

# %%
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0       10                1               3               10       4
# 1       20                1               3               10       4
# 2       20                1               3               10       4
# 3       10                1               5               10       8
# 4       10                1               1                0       4
# ..     ...              ...             ...              ...     ...
# 818     10                2              10                0       4
# 819     10                2              10                0       4
# 820     10                2              10                0       4
# 821     10                2              10                0       4
# 822     20                2               6               10       8
#
#      ram_type   ssd   hdd  os  os_bit  graphic_card_gb  weight  warranty  \
# ...

# %%
df[['Touchscreen']]
# Out:
#     Touchscreen
# 0            No
# 1            No
# 2            No
# 3            No
# 4            No
# ..          ...
# 818          No
# 819          No
# 820          No
# 821          No
# 822          No
#
# [786 rows x 1 columns]

# %%
df['Touchscreen'].unique()
# Out:
# <StringArray>
# ['No', 'Yes']
# Length: 2, dtype: str

# %%
df['Touchscreen'].value_counts()
# Out:
# Touchscreen
# No     694
# Yes     92
# Name: count, dtype: int64

# %%
Touchscreen_dict={
    'No':0, 'Yes':1
}

# %%
df['Touchscreen']=df['Touchscreen'].map(Touchscreen_dict)

# %%
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0       10                1               3               10       4
# 1       20                1               3               10       4
# 2       20                1               3               10       4
# 3       10                1               5               10       8
# 4       10                1               1                0       4
# ..     ...              ...             ...              ...     ...
# 818     10                2              10                0       4
# 819     10                2              10                0       4
# 820     10                2              10                0       4
# 821     10                2              10                0       4
# 822     20                2               6               10       8
#
#      ram_type   ssd   hdd  os  os_bit  graphic_card_gb  weight  warranty  \
# ...

# %%
df[['msoffice']]
# Out:
#     msoffice
# 0         No
# 1         No
# 2         No
# 3         No
# 4         No
# ..       ...
# 818       No
# 819       No
# 820       No
# 821       No
# 822       No
#
# [786 rows x 1 columns]

# %%
df['msoffice'].unique()
# Out:
# <StringArray>
# ['No', 'Yes']
# Length: 2, dtype: str

# %%
df['msoffice'].value_counts()
# Out:
# msoffice
# No     512
# Yes    274
# Name: count, dtype: int64

# %%
msoffice_dict={
    'No':0, 'Yes':1
}

# %%
df['msoffice']=df['msoffice'].map(msoffice_dict)

# %%
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0       10                1               3               10       4
# 1       20                1               3               10       4
# 2       20                1               3               10       4
# 3       10                1               5               10       8
# 4       10                1               1                0       4
# ..     ...              ...             ...              ...     ...
# 818     10                2              10                0       4
# 819     10                2              10                0       4
# 820     10                2              10                0       4
# 821     10                2              10                0       4
# 822     20                2               6               10       8
#
#      ram_type   ssd   hdd  os  os_bit  graphic_card_gb  weight  warranty  \
# ...

# %%
# df.to_csv('clean_laptopPrice.csv')

# %%
x=df.drop('Price',axis=1)

# %%
x
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0       10                1               3               10       4
# 1       20                1               3               10       4
# 2       20                1               3               10       4
# 3       10                1               5               10       8
# 4       10                1               1                0       4
# ..     ...              ...             ...              ...     ...
# 818     10                2              10                0       4
# 819     10                2              10                0       4
# 820     10                2              10                0       4
# 821     10                2              10                0       4
# 822     20                2               6               10       8
#
#      ram_type   ssd   hdd  os  os_bit  graphic_card_gb  weight  warranty  \
# ...

# %%
y=df[['Price']]

# %%
y
# Out:
#       Price
# 0     34649
# 1     38999
# 2     39999
# 3     69990
# 4     26990
# ..      ...
# 818  135990
# 819  144990
# 820  149990
# 821  142990
# 822   57490
#
# [786 rows x 1 columns]

# %%
# pip install scikit-learn

# %%
# pip install matplotlib

# %%
# pip install seaborn

# %%
# pip install numpy

# %%
import sklearn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVC,SVR
import joblib

# %%
from sklearn.model_selection import train_test_split
x_train , x_test ,y_train ,y_test =train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (628, 15) (158, 15) (628, 1) (158, 1)

# %%
x_train
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 218     50                1               5               11      16
# 140     10                1               3               11       8
# 778     10                2               8                0      16
# 546     10                1               7               10      16
# 57      50                1               3               11       4
# ..     ...              ...             ...              ...     ...
# 73      20                1               3               10       4
# 112     10                1               3               11       8
# 281     20                1               5               11       8
# 456     10                1               5               11      16
# 108     60                1               3               11       8
#
#      ram_type   ssd   hdd  os  os_bit  graphic_card_gb  weight  warranty  \
# ...

# %%
y_train
# Out:
#       Price
# 218   67990
# 140   38900
# 778  112990
# 546  224990
# 57    44900
# ..      ...
# 73    41990
# 112   44990
# 281   54990
# 456   64990
# 108   60790
#
# [628 rows x 1 columns]

# %%
x_test
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 789     10                2               8                0       4
# 40      60                1               3               10       4
# 219     10                1               5               10       8
# 207     30                1               5                7       8
# 243     50                1               5               11       8
# ..     ...              ...             ...              ...     ...
# 82      60                1               3               11       8
# 155     60                1               3               10       4
# 347     60                1               5               11       8
# 519     50                1               7               11      16
# 464     20                1               5               10       8
#
#      ram_type   ssd   hdd  os  os_bit  graphic_card_gb  weight  warranty  \
# ...

# %%
y_test
# Out:
#      Price
# 789  99990
# 40   36990
# 219  57990
# 207  86867
# 243  58340
# ..     ...
# 82   48500
# 155  43000
# 347  71990
# 519  99999
# 464  74590
#
# [158 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
joblib.dump(lr,"linear_model.lb")
# Out:
# ['linear_model.lb']

# %%
model=joblib.load('linear_model.lb')

# %%
model.predict(x_test)
# Out:
# array([[144361.99722067],
#        [ 27194.91334494],
#        [ 74054.98792735],
#        [ 68606.81444972],
#        [ 57707.52159241],
#        [ 72482.73013746],
#        [157360.36830263],
#        [ 26869.47015683],
#        [200257.32447714],
#        [ 25997.01133511],
#        [ 73142.17108016],
#        [ 58336.94213444],
#        [ 43695.17060685],
#        [149141.71705482],
#        [ 43695.17060685],
#        [ 27734.32712803],
#        [158722.8104221 ],
#        [ 49298.44222149],
#        [152963.95287617],
#        [ 96206.01427371],
#        [119158.80152054],
#        [ 75901.2092446 ],
#        [ 72700.20338323],
#        [ 77445.32337058],
#        [ 28100.74277822],
#        [ 56209.49500549],
#        [ 30009.68338205],
#        [ 91294.92734603],
#        [ 71406.97109385],
#        [ 73876.66826044],
#        [ 71906.31328949],
#        [ 96206.01427371],
#        [ 74509.68092617],
#        [ 47886.31979781],
#        [ 48249.78045236],
# ...

# %%
x_test
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 789     10                2               8                0       4
# 40      60                1               3               10       4
# 219     10                1               5               10       8
# 207     30                1               5                7       8
# 243     50                1               5               11       8
# ..     ...              ...             ...              ...     ...
# 82      60                1               3               11       8
# 155     60                1               3               10       4
# 347     60                1               5               11       8
# 519     50                1               7               11      16
# 464     20                1               5               10       8
#
#      ram_type   ssd   hdd  os  os_bit  graphic_card_gb  weight  warranty  \
# ...

# %%
pred =lr.predict(x_test)

# %%
pred
# Out:
# array([[144361.99722067],
#        [ 27194.91334494],
#        [ 74054.98792735],
#        [ 68606.81444972],
#        [ 57707.52159241],
#        [ 72482.73013746],
#        [157360.36830263],
#        [ 26869.47015683],
#        [200257.32447714],
#        [ 25997.01133511],
#        [ 73142.17108016],
#        [ 58336.94213444],
#        [ 43695.17060685],
#        [149141.71705482],
#        [ 43695.17060685],
#        [ 27734.32712803],
#        [158722.8104221 ],
#        [ 49298.44222149],
#        [152963.95287617],
#        [ 96206.01427371],
#        [119158.80152054],
#        [ 75901.2092446 ],
#        [ 72700.20338323],
#        [ 77445.32337058],
#        [ 28100.74277822],
#        [ 56209.49500549],
#        [ 30009.68338205],
#        [ 91294.92734603],
#        [ 71406.97109385],
#        [ 73876.66826044],
#        [ 71906.31328949],
#        [ 96206.01427371],
#        [ 74509.68092617],
#        [ 47886.31979781],
#        [ 48249.78045236],
# ...

# %%
df['brand'].unique()
# Out:
# array([10, 20, 30, 40, 50, 60, 70, 80])

# %%
x
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0       10                1               3               10       4
# 1       20                1               3               10       4
# 2       20                1               3               10       4
# 3       10                1               5               10       8
# 4       10                1               1                0       4
# ..     ...              ...             ...              ...     ...
# 818     10                2              10                0       4
# 819     10                2              10                0       4
# 820     10                2              10                0       4
# 821     10                2              10                0       4
# 822     20                2               6               10       8
#
#      ram_type   ssd   hdd  os  os_bit  graphic_card_gb  weight  warranty  \
# ...

# %% [markdown]
# solve/using SVR

# %%
# sv=SVR()

# %%
# sv.fit(x_train, y_train)

# %%
# sv.score(x_train,y_train)

# %%
# sv.score(x_test,y_test)

# %%
# pred=sv.predict(x_test)

# %%
# pred

# %%
# y_test

# %%
# df['Price'].value_counts()

# %% [markdown]
# sv=SVR
